# %% [markdown]
# ## Project - Face Mask Detection
# - **Data Preparation & Preprocessing**

# %%
# import libraries
import os
import numpy as np
import pandas as pd
import cv2
import gc#garbage collect, as we are working on big data, to stop the computer from not responding, we will clean the data/garbage collections using gc
from tqdm import tqdm # will be used for the loops
from glob import glob

#os and glob are used to extract the path to prepare the data accordingly (Labelling the folder)

# %% [markdown]
# ### Collecting & Labelling our data
# - Collecting all data
# - labeling

# %%
dirs = os.listdir('Data')
print(dirs)
# Out:
# ['Mask', 'Mask_Chin', 'Mask_Mouth_Chin', 'Mask_Nose_Mouth']

# %%
path = glob('./Data/Mask/*.jpg') #checking if the Folder Mask has data (testing)

# %%
path
# Out:
# ['./Data/Mask\\00000.jpg',
#  './Data/Mask\\00001.jpg',
#  './Data/Mask\\00002.jpg',
#  './Data/Mask\\00003.jpg',
#  './Data/Mask\\00004.jpg',
#  './Data/Mask\\00005.jpg',
#  './Data/Mask\\00006.jpg',
#  './Data/Mask\\00007.jpg',
#  './Data/Mask\\00008.jpg',
#  './Data/Mask\\00009.jpg',
#  './Data/Mask\\00010.jpg',
#  './Data/Mask\\00011.jpg',
#  './Data/Mask\\00012.jpg',
#  './Data/Mask\\00013.jpg',
#  './Data/Mask\\00014.jpg',
#  './Data/Mask\\00015.jpg',
#  './Data/Mask\\00016.jpg',
#  './Data/Mask\\00017.jpg',
#  './Data/Mask\\00018.jpg',
#  './Data/Mask\\00019.jpg',
#  './Data/Mask\\00020.jpg',
#  './Data/Mask\\00021.jpg',
#  './Data/Mask\\00022.jpg',
#  './Data/Mask\\00023.jpg',
#  './Data/Mask\\00024.jpg',
#  './Data/Mask\\00025.jpg',
#  './Data/Mask\\00026.jpg',
#  './Data/Mask\\00027.jpg',
#  './Data/Mask\\00028.jpg',
#  './Data/Mask\\00029.jpg',
#  './Data/Mask\\00030.jpg',
#  './Data/Mask\\00031.jpg',
#  './Data/Mask\\00032.jpg',
#  './Data/Mask\\00033.jpg',
#  './Data/Mask\\00034.jpg',
#  './Data/Mask\\00035.jpg',
#  './Data/Mask\\00036.jpg',
#  './Data/Mask\\00037.jpg',
#  './Data/Mask\\00038.jpg',
#  './Data/Mask\\00039.jpg',
#  './Data/Mask\\00040.jpg',
#  './Data/Mask\\00041.jpg',
#  './Data/Mask\\00042.jpg',
#  './Data/Mask\\00043.jpg',
#  './Data/Mask\\00044.jpg',
#  './Data/Mask\\00045.jpg',
#  './Data/Mask\\00046.jpg',
#  './Data/Mask\\00047.jpg',
#  './Data/Mask\\00048.jpg',
#  './Data/Mask\\00049.jpg',
#  './Data/Mask\\00050.jpg',
#  './Data/Mask\\00051.jpg',
#  './Data/Mask\\00052.jpg',
#  './Data/Mask\\00053.jpg',
#  './Data/Mask\\00054.jpg',
#  './Data/Mask\\00055.jpg',
#  './Data/Mask\\00056.jpg',
#  './Data/Mask\\00057.jpg',
#  './Data/Mask\\00058.jpg',
#  './Data/Mask\\00059.jpg',
#  './Data/Mask\\00060.jpg',
#  './Data/Mask\\00061.jpg',
#  './Data/Mask\\00062.jpg',
#  './Data/Mask\\00063.jpg',
#  './Data/Mask\\00064.jpg',
#  './Data/Mask\\00065.jpg',
#  './Data/Mask\\00066.jpg',
#  './Data/Mask\\00067.jpg',
#  './Data/Mask\\00068.jpg',
#  './Data/Mask\\00069.jpg',
#  './Data/Mask\\00070.jpg',
#  './Data/Mask\\00071.jpg',
#  './Data/Mask\\00072.jpg',
#  './Data/Mask\\00073.jpg',
#  './Data/Mask\\00074.jpg',
#  './Data/Mask\\00075.jpg',
#  './Data/Mask\\00076.jpg',
#  './Data/Mask\\00077.jpg',
#  './Data/Mask\\00078.jpg',
#  './Data/Mask\\00079.jpg',
#  './Data/Mask\\00080.jpg',
#  './Data/Mask\\00081.jpg',
#  './Data/Mask\\00082.jpg',
#  './Data/Mask\\00083.jpg',
#  './Data/Mask\\00084.jpg',
#  './Data/Mask\\00085.jpg',
#  './Data/Mask\\00086.jpg',
#  './Data/Mask\\00087.jpg',
#  './Data/Mask\\00088.jpg',
#  './Data/Mask\\00089.jpg',
#  './Data/Mask\\00090.jpg',
#  './Data/Mask\\00091.jpg',
#  './Data/Mask\\00092.jpg',
#  './Data/Mask\\00093.jpg',
#  './Data/Mask\\00094.jpg',
#  './Data/Mask\\00095.jpg',
#  './Data/Mask\\00096.jpg',
#  './Data/Mask\\00097.jpg',
#  './Data/Mask\\00098.jpg',
#  './Data/Mask\\00099.jpg',
#  './Data/Mask\\00100.jpg',
#  './Data/Mask\\00101.jpg',
#  './Data/Mask\\00102.jpg',
#  './Data/Mask\\00103.jpg',
#  './Data/Mask\\00104.jpg',
#  './Data/Mask\\00105.jpg',
#  './Data/Mask\\00106.jpg',
#  './Data/Mask\\00107.jpg',
#  './Data/Mask\\00108.jpg',
#  './Data/Mask\\00109.jpg',
#  './Data/Mask\\00110.jpg',
#  './Data/Mask\\00111.jpg',
#  './Data/Mask\\00112.jpg',
#  './Data/Mask\\00113.jpg',
#  './Data/Mask\\00114.jpg',
#  './Data/Mask\\00115.jpg',
#  './Data/Mask\\00116.jpg',
#  './Data/Mask\\00117.jpg',
#  './Data/Mask\\00118.jpg',
#  './Data/Mask\\00119.jpg',
#  './Data/Mask\\00120.jpg',
#  './Data/Mask\\00121.jpg',
#  './Data/Mask\\00122.jpg',
#  './Data/Mask\\00123.jpg',
#  './Data/Mask\\00124.jpg',
#  './Data/Mask\\00125.jpg',
#  './Data/Mask\\00126.jpg',
#  './Data/Mask\\00127.jpg',
#  './Data/Mask\\00128.jpg',
#  './Data/Mask\\00129.jpg',
#  './Data/Mask\\00130.jpg',
#  './Data/Mask\\00131.jpg',
#  './Data/Mask\\00132.jpg',
#  './Data/Mask\\00133.jpg',
#  './Data/Mask\\00134.jpg',
#  './Data/Mask\\00135.jpg',
#  './Data/Mask\\00136.jpg',
#  './Data/Mask\\00137.jpg',
#  './Data/Mask\\00138.jpg',
#  './Data/Mask\\00139.jpg',
#  './Data/Mask\\00140.jpg',
#  './Data/Mask\\00141.jpg',
#  './Data/Mask\\00142.jpg',
#  './Data/Mask\\00143.jpg',
#  './Data/Mask\\00144.jpg',
#  './Data/Mask\\00145.jpg',
#  './Data/Mask\\00146.jpg',
#  './Data/Mask\\00147.jpg',
#  './Data/Mask\\00148.jpg',
#  './Data/Mask\\00149.jpg',
#  './Data/Mask\\00150.jpg',
#  './Data/Mask\\00151.jpg',
#  './Data/Mask\\00152.jpg',
#  './Data/Mask\\00153.jpg',
#  './Data/Mask\\00154.jpg',
#  './Data/Mask\\00155.jpg',
#  './Data/Mask\\00156.jpg',
#  './Data/Mask\\00157.jpg',
#  './Data/Mask\\00158.jpg',
#  './Data/Mask\\00159.jpg',
#  './Data/Mask\\00160.jpg',
#  './Data/Mask\\00161.jpg',
#  './Data/Mask\\00162.jpg',
#  './Data/Mask\\00163.jpg',
#  './Data/Mask\\00164.jpg',
#  './Data/Mask\\00165.jpg',
#  './Data/Mask\\00166.jpg',
#  './Data/Mask\\00167.jpg',
#  './Data/Mask\\00168.jpg',
#  './Data/Mask\\00169.jpg',
#  './Data/Mask\\00170.jpg',
#  './Data/Mask\\00171.jpg',
#  './Data/Mask\\00172.jpg',
#  './Data/Mask\\00173.jpg',
#  './Data/Mask\\00174.jpg',
#  './Data/Mask\\00175.jpg',
#  './Data/Mask\\00176.jpg',
#  './Data/Mask\\00177.jpg',
#  './Data/Mask\\00178.jpg',
#  './Data/Mask\\00179.jpg',
#  './Data/Mask\\00180.jpg',
#  './Data/Mask\\00181.jpg',
#  './Data/Mask\\00182.jpg',
#  './Data/Mask\\00183.jpg',
#  './Data/Mask\\00184.jpg',
#  './Data/Mask\\00185.jpg',
#  './Data/Mask\\00186.jpg',
#  './Data/Mask\\00187.jpg',
#  './Data/Mask\\00188.jpg',
#  './Data/Mask\\00189.jpg',
#  './Data/Mask\\00190.jpg',
#  './Data/Mask\\00191.jpg',
#  './Data/Mask\\00192.jpg',
#  './Data/Mask\\00193.jpg',
#  './Data/Mask\\00194.jpg',
#  './Data/Mask\\00195.jpg',
#  './Data/Mask\\00196.jpg',
#  './Data/Mask\\00197.jpg',
#  './Data/Mask\\00198.jpg',
#  './Data/Mask\\00199.jpg',
#  './Data/Mask\\00200.jpg',
#  './Data/Mask\\00201.jpg',
#  './Data/Mask\\00202.jpg',
#  './Data/Mask\\00203.jpg',
#  './Data/Mask\\00204.jpg',
#  './Data/Mask\\00205.jpg',
#  './Data/Mask\\00206.jpg',
#  './Data/Mask\\00207.jpg',
#  './Data/Mask\\00208.jpg',
#  './Data/Mask\\00209.jpg',
#  './Data/Mask\\00210.jpg',
#  './Data/Mask\\00211.jpg',
#  './Data/Mask\\00212.jpg',
#  './Data/Mask\\00213.jpg',
#  './Data/Mask\\00214.jpg',
#  './Data/Mask\\00215.jpg',
#  './Data/Mask\\00216.jpg',
#  './Data/Mask\\00217.jpg',
#  './Data/Mask\\00218.jpg',
#  './Data/Mask\\00219.jpg',
#  './Data/Mask\\00220.jpg',
#  './Data/Mask\\00221.jpg',
#  './Data/Mask\\00222.jpg',
#  './Data/Mask\\00223.jpg',
#  './Data/Mask\\00224.jpg',
#  './Data/Mask\\00225.jpg',
#  './Data/Mask\\00226.jpg',
#  './Data/Mask\\00227.jpg',
#  './Data/Mask\\00228.jpg',
#  './Data/Mask\\00229.jpg',
#  './Data/Mask\\00230.jpg',
#  './Data/Mask\\00231.jpg',
#  './Data/Mask\\00232.jpg',
#  './Data/Mask\\00233.jpg',
#  './Data/Mask\\00234.jpg',
#  './Data/Mask\\00235.jpg',
#  './Data/Mask\\00236.jpg',
#  './Data/Mask\\00237.jpg',
#  './Data/Mask\\00238.jpg',
#  './Data/Mask\\00239.jpg',
#  './Data/Mask\\00240.jpg',
#  './Data/Mask\\00241.jpg',
#  './Data/Mask\\00242.jpg',
#  './Data/Mask\\00243.jpg',
#  './Data/Mask\\00244.jpg',
#  './Data/Mask\\00245.jpg',
#  './Data/Mask\\00246.jpg',
#  './Data/Mask\\00247.jpg',
#  './Data/Mask\\00248.jpg',
#  './Data/Mask\\00249.jpg',
#  './Data/Mask\\00250.jpg',
#  './Data/Mask\\00251.jpg',
#  './Data/Mask\\00252.jpg',
#  './Data/Mask\\00253.jpg',
#  './Data/Mask\\00254.jpg',
#  './Data/Mask\\00255.jpg',
#  './Data/Mask\\00256.jpg',
#  './Data/Mask\\00257.jpg',
#  './Data/Mask\\00258.jpg',
#  './Data/Mask\\00259.jpg',
#  './Data/Mask\\00260.jpg',
#  './Data/Mask\\00261.jpg',
#  './Data/Mask\\00262.jpg',
#  './Data/Mask\\00263.jpg',
#  './Data/Mask\\00264.jpg',
#  './Data/Mask\\00265.jpg',
#  './Data/Mask\\00266.jpg',
#  './Data/Mask\\00267.jpg',
#  './Data/Mask\\00268.jpg',
#  './Data/Mask\\00269.jpg',
#  './Data/Mask\\00270.jpg',
#  './Data/Mask\\00271.jpg',
#  './Data/Mask\\00272.jpg',
#  './Data/Mask\\00273.jpg',
#  './Data/Mask\\00274.jpg',
#  './Data/Mask\\00275.jpg',
#  './Data/Mask\\00276.jpg',
#  './Data/Mask\\00277.jpg',
#  './Data/Mask\\00278.jpg',
#  './Data/Mask\\00279.jpg',
#  './Data/Mask\\00280.jpg',
#  './Data/Mask\\00281.jpg',
#  './Data/Mask\\00282.jpg',
#  './Data/Mask\\00283.jpg',
#  './Data/Mask\\00284.jpg',
#  './Data/Mask\\00285.jpg',
#  './Data/Mask\\00286.jpg',
#  './Data/Mask\\00287.jpg',
#  './Data/Mask\\00288.jpg',
#  './Data/Mask\\00289.jpg',
#  './Data/Mask\\00290.jpg',
#  './Data/Mask\\00291.jpg',
#  './Data/Mask\\00292.jpg',
#  './Data/Mask\\00293.jpg',
#  './Data/Mask\\00294.jpg',
#  './Data/Mask\\00295.jpg',
#  './Data/Mask\\00296.jpg',
#  './Data/Mask\\00297.jpg',
#  './Data/Mask\\00298.jpg',
#  './Data/Mask\\00299.jpg',
#  './Data/Mask\\00300.jpg',
#  './Data/Mask\\00301.jpg',
#  './Data/Mask\\00302.jpg',
#  './Data/Mask\\00303.jpg',
#  './Data/Mask\\00304.jpg',
#  './Data/Mask\\00305.jpg',
#  './Data/Mask\\00306.jpg',
#  './Data/Mask\\00307.jpg',
#  './Data/Mask\\00308.jpg',
#  './Data/Mask\\00309.jpg',
#  './Data/Mask\\00310.jpg',
#  './Data/Mask\\00311.jpg',
#  './Data/Mask\\00312.jpg',
#  './Data/Mask\\00313.jpg',
#  './Data/Mask\\00314.jpg',
#  './Data/Mask\\00315.jpg',
#  './Data/Mask\\00316.jpg',
#  './Data/Mask\\00317.jpg',
#  './Data/Mask\\00318.jpg',
#  './Data/Mask\\00319.jpg',
#  './Data/Mask\\00320.jpg',
#  './Data/Mask\\00321.jpg',
#  './Data/Mask\\00322.jpg',
#  './Data/Mask\\00323.jpg',
#  './Data/Mask\\00324.jpg',
#  './Data/Mask\\00325.jpg',
#  './Data/Mask\\00326.jpg',
#  './Data/Mask\\00327.jpg',
#  './Data/Mask\\00328.jpg',
#  './Data/Mask\\00329.jpg',
#  './Data/Mask\\00330.jpg',
#  './Data/Mask\\00331.jpg',
#  './Data/Mask\\00332.jpg',
#  './Data/Mask\\00333.jpg',
#  './Data/Mask\\00334.jpg',
#  './Data/Mask\\00335.jpg',
#  './Data/Mask\\00336.jpg',
#  './Data/Mask\\00337.jpg',
#  './Data/Mask\\00338.jpg',
#  './Data/Mask\\00339.jpg',
#  './Data/Mask\\00340.jpg',
#  './Data/Mask\\00341.jpg',
#  './Data/Mask\\00342.jpg',
#  './Data/Mask\\00343.jpg',
#  './Data/Mask\\00344.jpg',
#  './Data/Mask\\00345.jpg',
#  './Data/Mask\\00346.jpg',
#  './Data/Mask\\00347.jpg',
#  './Data/Mask\\00348.jpg',
#  './Data/Mask\\00349.jpg',
#  './Data/Mask\\00350.jpg',
#  './Data/Mask\\00351.jpg',
#  './Data/Mask\\00352.jpg',
#  './Data/Mask\\00353.jpg',
#  './Data/Mask\\00354.jpg',
#  './Data/Mask\\00355.jpg',
#  './Data/Mask\\00356.jpg',
#  './Data/Mask\\00357.jpg',
#  './Data/Mask\\00358.jpg',
#  './Data/Mask\\00359.jpg',
#  './Data/Mask\\00360.jpg',
#  './Data/Mask\\00361.jpg',
#  './Data/Mask\\00362.jpg',
#  './Data/Mask\\00363.jpg',
#  './Data/Mask\\00364.jpg',
#  './Data/Mask\\00365.jpg',
#  './Data/Mask\\00366.jpg',
#  './Data/Mask\\00367.jpg',
#  './Data/Mask\\00368.jpg',
#  './Data/Mask\\00369.jpg',
#  './Data/Mask\\00370.jpg',
#  './Data/Mask\\00371.jpg',
#  './Data/Mask\\00372.jpg',
#  './Data/Mask\\00373.jpg',
#  './Data/Mask\\00374.jpg',
#  './Data/Mask\\00375.jpg',
#  './Data/Mask\\00376.jpg',
#  './Data/Mask\\00377.jpg',
#  './Data/Mask\\00378.jpg',
#  './Data/Mask\\00379.jpg',
#  './Data/Mask\\00380.jpg',
#  './Data/Mask\\00381.jpg',
#  './Data/Mask\\00382.jpg',
#  './Data/Mask\\00383.jpg',
#  './Data/Mask\\00384.jpg',
#  './Data/Mask\\00385.jpg',
#  './Data/Mask\\00386.jpg',
#  './Data/Mask\\00387.jpg',
#  './Data/Mask\\00388.jpg',
#  './Data/Mask\\00389.jpg',
#  './Data/Mask\\00390.jpg',
#  './Data/Mask\\00391.jpg',
#  './Data/Mask\\00392.jpg',
#  './Data/Mask\\00393.jpg',
#  './Data/Mask\\00394.jpg',
#  './Data/Mask\\00395.jpg',
#  './Data/Mask\\00396.jpg',
#  './Data/Mask\\00397.jpg',
#  './Data/Mask\\00398.jpg',
#  './Data/Mask\\00399.jpg',
#  './Data/Mask\\00400.jpg',
#  './Data/Mask\\00401.jpg',
#  './Data/Mask\\00402.jpg',
#  './Data/Mask\\00403.jpg',
#  './Data/Mask\\00404.jpg',
#  './Data/Mask\\00405.jpg',
#  './Data/Mask\\00406.jpg',
#  './Data/Mask\\00407.jpg',
#  './Data/Mask\\00408.jpg',
#  './Data/Mask\\00409.jpg',
#  './Data/Mask\\00410.jpg',
#  './Data/Mask\\00411.jpg',
#  './Data/Mask\\00412.jpg',
#  './Data/Mask\\00413.jpg',
#  './Data/Mask\\00414.jpg',
#  './Data/Mask\\00415.jpg',
#  './Data/Mask\\00416.jpg',
#  './Data/Mask\\00417.jpg',
#  './Data/Mask\\00418.jpg',
#  './Data/Mask\\00419.jpg',
#  './Data/Mask\\00420.jpg',
#  './Data/Mask\\00421.jpg',
#  './Data/Mask\\00422.jpg',
#  './Data/Mask\\00423.jpg',
#  './Data/Mask\\00424.jpg',
#  './Data/Mask\\00425.jpg',
#  './Data/Mask\\00426.jpg',
#  './Data/Mask\\00427.jpg',
#  './Data/Mask\\00428.jpg',
#  './Data/Mask\\00429.jpg',
#  './Data/Mask\\00430.jpg',
#  './Data/Mask\\00431.jpg',
#  './Data/Mask\\00432.jpg',
#  './Data/Mask\\00433.jpg',
#  './Data/Mask\\00434.jpg',
#  './Data/Mask\\00435.jpg',
#  './Data/Mask\\00436.jpg',
#  './Data/Mask\\00437.jpg',
#  './Data/Mask\\00438.jpg',
#  './Data/Mask\\00439.jpg',
#  './Data/Mask\\00440.jpg',
#  './Data/Mask\\00441.jpg',
#  './Data/Mask\\00442.jpg',
#  './Data/Mask\\00443.jpg',
#  './Data/Mask\\00444.jpg',
#  './Data/Mask\\00445.jpg',
#  './Data/Mask\\00446.jpg',
#  './Data/Mask\\00447.jpg',
#  './Data/Mask\\00448.jpg',
#  './Data/Mask\\00449.jpg',
#  './Data/Mask\\00450.jpg',
#  './Data/Mask\\00451.jpg',
#  './Data/Mask\\00452.jpg',
#  './Data/Mask\\00453.jpg',
#  './Data/Mask\\00454.jpg',
#  './Data/Mask\\00455.jpg',
#  './Data/Mask\\00456.jpg',
#  './Data/Mask\\00457.jpg',
#  './Data/Mask\\00458.jpg',
#  './Data/Mask\\00459.jpg',
#  './Data/Mask\\00460.jpg',
#  './Data/Mask\\00461.jpg',
#  './Data/Mask\\00462.jpg',
#  './Data/Mask\\00463.jpg',
#  './Data/Mask\\00464.jpg',
#  './Data/Mask\\00465.jpg',
#  './Data/Mask\\00466.jpg',
#  './Data/Mask\\00467.jpg',
#  './Data/Mask\\00468.jpg',
#  './Data/Mask\\00469.jpg',
#  './Data/Mask\\00470.jpg',
#  './Data/Mask\\00471.jpg',
#  './Data/Mask\\00472.jpg',
#  './Data/Mask\\00473.jpg',
#  './Data/Mask\\00474.jpg',
#  './Data/Mask\\00475.jpg',
#  './Data/Mask\\00476.jpg',
#  './Data/Mask\\00477.jpg',
#  './Data/Mask\\00478.jpg',
#  './Data/Mask\\00479.jpg',
#  './Data/Mask\\00480.jpg',
#  './Data/Mask\\00481.jpg',
#  './Data/Mask\\00482.jpg',
#  './Data/Mask\\00483.jpg',
#  './Data/Mask\\00484.jpg',
#  './Data/Mask\\00485.jpg',
#  './Data/Mask\\00486.jpg',
#  './Data/Mask\\00487.jpg',
#  './Data/Mask\\00488.jpg',
#  './Data/Mask\\00489.jpg',
#  './Data/Mask\\00490.jpg',
#  './Data/Mask\\00491.jpg',
#  './Data/Mask\\00492.jpg',
#  './Data/Mask\\00493.jpg',
#  './Data/Mask\\00494.jpg',
#  './Data/Mask\\00495.jpg',
#  './Data/Mask\\00496.jpg',
#  './Data/Mask\\00497.jpg',
#  './Data/Mask\\00498.jpg',
#  './Data/Mask\\00499.jpg',
#  './Data/Mask\\00500.jpg',
#  './Data/Mask\\00501.jpg',
#  './Data/Mask\\00502.jpg',
#  './Data/Mask\\00503.jpg',
#  './Data/Mask\\00504.jpg',
#  './Data/Mask\\00505.jpg',
#  './Data/Mask\\00506.jpg',
#  './Data/Mask\\00507.jpg',
#  './Data/Mask\\00508.jpg',
#  './Data/Mask\\00509.jpg',
#  './Data/Mask\\00510.jpg',
#  './Data/Mask\\00511.jpg',
#  './Data/Mask\\00512.jpg',
#  './Data/Mask\\00513.jpg',
#  './Data/Mask\\00514.jpg',
#  './Data/Mask\\00515.jpg',
#  './Data/Mask\\00516.jpg',
#  './Data/Mask\\00517.jpg',
#  './Data/Mask\\00518.jpg',
#  './Data/Mask\\00519.jpg',
#  './Data/Mask\\00520.jpg',
#  './Data/Mask\\00521.jpg',
#  './Data/Mask\\00522.jpg',
#  './Data/Mask\\00523.jpg',
#  './Data/Mask\\00524.jpg',
#  './Data/Mask\\00525.jpg',
#  './Data/Mask\\00526.jpg',
#  './Data/Mask\\00527.jpg',
#  './Data/Mask\\00528.jpg',
#  './Data/Mask\\00529.jpg',
#  './Data/Mask\\00530.jpg',
#  './Data/Mask\\00531.jpg',
#  './Data/Mask\\00532.jpg',
#  './Data/Mask\\00533.jpg',
#  './Data/Mask\\00534.jpg',
#  './Data/Mask\\00535.jpg',
#  './Data/Mask\\00536.jpg',
#  './Data/Mask\\00537.jpg',
#  './Data/Mask\\00538.jpg',
#  './Data/Mask\\00539.jpg',
#  './Data/Mask\\00540.jpg',
#  './Data/Mask\\00541.jpg',
#  './Data/Mask\\00542.jpg',
#  './Data/Mask\\00543.jpg',
#  './Data/Mask\\00544.jpg',
#  './Data/Mask\\00545.jpg',
#  './Data/Mask\\00546.jpg',
#  './Data/Mask\\00547.jpg',
#  './Data/Mask\\00548.jpg',
#  './Data/Mask\\00549.jpg',
#  './Data/Mask\\00550.jpg',
#  './Data/Mask\\00551.jpg',
#  './Data/Mask\\00552.jpg',
#  './Data/Mask\\00553.jpg',
#  './Data/Mask\\00554.jpg',
#  './Data/Mask\\00555.jpg',
#  './Data/Mask\\00556.jpg',
#  './Data/Mask\\00557.jpg',
#  './Data/Mask\\00558.jpg',
#  './Data/Mask\\00559.jpg',
#  './Data/Mask\\00560.jpg',
#  './Data/Mask\\00561.jpg',
#  './Data/Mask\\00562.jpg',
#  './Data/Mask\\00563.jpg',
#  './Data/Mask\\00564.jpg',
#  './Data/Mask\\00565.jpg',
#  './Data/Mask\\00566.jpg',
#  './Data/Mask\\00567.jpg',
#  './Data/Mask\\00568.jpg',
#  './Data/Mask\\00569.jpg',
#  './Data/Mask\\00570.jpg',
#  './Data/Mask\\00571.jpg',
#  './Data/Mask\\00572.jpg',
#  './Data/Mask\\00573.jpg',
#  './Data/Mask\\00574.jpg',
#  './Data/Mask\\00575.jpg',
#  './Data/Mask\\00576.jpg',
#  './Data/Mask\\00577.jpg',
#  './Data/Mask\\00578.jpg',
#  './Data/Mask\\00579.jpg',
#  './Data/Mask\\00580.jpg',
#  './Data/Mask\\00581.jpg',
#  './Data/Mask\\00582.jpg',
#  './Data/Mask\\00583.jpg',
#  './Data/Mask\\00584.jpg',
#  './Data/Mask\\00585.jpg',
#  './Data/Mask\\00586.jpg',
#  './Data/Mask\\00587.jpg',
#  './Data/Mask\\00588.jpg',
#  './Data/Mask\\00589.jpg',
#  './Data/Mask\\00590.jpg',
#  './Data/Mask\\00591.jpg',
#  './Data/Mask\\00592.jpg',
#  './Data/Mask\\00593.jpg',
#  './Data/Mask\\00594.jpg',
#  './Data/Mask\\00595.jpg',
#  './Data/Mask\\00596.jpg',
#  './Data/Mask\\00597.jpg',
#  './Data/Mask\\00598.jpg',
#  './Data/Mask\\00599.jpg',
#  './Data/Mask\\00600.jpg',
#  './Data/Mask\\00601.jpg',
#  './Data/Mask\\00602.jpg',
#  './Data/Mask\\00603.jpg',
#  './Data/Mask\\00604.jpg',
#  './Data/Mask\\00605.jpg',
#  './Data/Mask\\00606.jpg',
#  './Data/Mask\\00607.jpg',
#  './Data/Mask\\00608.jpg',
#  './Data/Mask\\00609.jpg',
#  './Data/Mask\\00610.jpg',
#  './Data/Mask\\00611.jpg',
#  './Data/Mask\\00612.jpg',
#  './Data/Mask\\00613.jpg',
#  './Data/Mask\\00614.jpg',
#  './Data/Mask\\00615.jpg',
#  './Data/Mask\\00616.jpg',
#  './Data/Mask\\00617.jpg',
#  './Data/Mask\\00618.jpg',
#  './Data/Mask\\00619.jpg',
#  './Data/Mask\\00620.jpg',
#  './Data/Mask\\00621.jpg',
#  './Data/Mask\\00622.jpg',
#  './Data/Mask\\00623.jpg',
#  './Data/Mask\\00624.jpg',
#  './Data/Mask\\00625.jpg',
#  './Data/Mask\\00626.jpg',
#  './Data/Mask\\00627.jpg',
#  './Data/Mask\\00628.jpg',
#  './Data/Mask\\00629.jpg',
#  './Data/Mask\\00630.jpg',
#  './Data/Mask\\00631.jpg',
#  './Data/Mask\\00632.jpg',
#  './Data/Mask\\00633.jpg',
#  './Data/Mask\\00634.jpg',
#  './Data/Mask\\00635.jpg',
#  './Data/Mask\\00636.jpg',
#  './Data/Mask\\00637.jpg',
#  './Data/Mask\\00638.jpg',
#  './Data/Mask\\00639.jpg',
#  './Data/Mask\\00640.jpg',
#  './Data/Mask\\00641.jpg',
#  './Data/Mask\\00642.jpg',
#  './Data/Mask\\00643.jpg',
#  './Data/Mask\\00644.jpg',
#  './Data/Mask\\00645.jpg',
#  './Data/Mask\\00646.jpg',
#  './Data/Mask\\00647.jpg',
#  './Data/Mask\\00648.jpg',
#  './Data/Mask\\00649.jpg',
#  './Data/Mask\\00650.jpg',
#  './Data/Mask\\00651.jpg',
#  './Data/Mask\\00652.jpg',
#  './Data/Mask\\00653.jpg',
#  './Data/Mask\\00654.jpg',
#  './Data/Mask\\00655.jpg',
#  './Data/Mask\\00656.jpg',
#  './Data/Mask\\00657.jpg',
#  './Data/Mask\\00658.jpg',
#  './Data/Mask\\00659.jpg',
#  './Data/Mask\\00660.jpg',
#  './Data/Mask\\00661.jpg',
#  './Data/Mask\\00662.jpg',
#  './Data/Mask\\00663.jpg',
#  './Data/Mask\\00664.jpg',
#  './Data/Mask\\00665.jpg',
#  './Data/Mask\\00666.jpg',
#  './Data/Mask\\00667.jpg',
#  './Data/Mask\\00668.jpg',
#  './Data/Mask\\00669.jpg',
#  './Data/Mask\\00670.jpg',
#  './Data/Mask\\00671.jpg',
#  './Data/Mask\\00672.jpg',
#  './Data/Mask\\00673.jpg',
#  './Data/Mask\\00674.jpg',
#  './Data/Mask\\00675.jpg',
#  './Data/Mask\\00676.jpg',
#  './Data/Mask\\00677.jpg',
#  './Data/Mask\\00678.jpg',
#  './Data/Mask\\00679.jpg',
#  './Data/Mask\\00680.jpg',
#  './Data/Mask\\00681.jpg',
#  './Data/Mask\\00682.jpg',
#  './Data/Mask\\00683.jpg',
#  './Data/Mask\\00684.jpg',
#  './Data/Mask\\00685.jpg',
#  './Data/Mask\\00686.jpg',
#  './Data/Mask\\00687.jpg',
#  './Data/Mask\\00688.jpg',
#  './Data/Mask\\00689.jpg',
#  './Data/Mask\\00690.jpg',
#  './Data/Mask\\00691.jpg',
#  './Data/Mask\\00692.jpg',
#  './Data/Mask\\00693.jpg',
#  './Data/Mask\\00694.jpg',
#  './Data/Mask\\00695.jpg',
#  './Data/Mask\\00696.jpg',
#  './Data/Mask\\00697.jpg',
#  './Data/Mask\\00698.jpg',
#  './Data/Mask\\00699.jpg',
#  './Data/Mask\\00700.jpg',
#  './Data/Mask\\00701.jpg',
#  './Data/Mask\\00702.jpg',
#  './Data/Mask\\00703.jpg',
#  './Data/Mask\\00704.jpg',
#  './Data/Mask\\00705.jpg',
#  './Data/Mask\\00706.jpg',
#  './Data/Mask\\00707.jpg',
#  './Data/Mask\\00708.jpg',
#  './Data/Mask\\00709.jpg',
#  './Data/Mask\\00710.jpg',
#  './Data/Mask\\00711.jpg',
#  './Data/Mask\\00712.jpg',
#  './Data/Mask\\00713.jpg',
#  './Data/Mask\\00714.jpg',
#  './Data/Mask\\00715.jpg',
#  './Data/Mask\\00716.jpg',
#  './Data/Mask\\00717.jpg',
#  './Data/Mask\\00718.jpg',
#  './Data/Mask\\00719.jpg',
#  './Data/Mask\\00720.jpg',
#  './Data/Mask\\00721.jpg',
#  './Data/Mask\\00722.jpg',
#  './Data/Mask\\00723.jpg',
#  './Data/Mask\\00724.jpg',
#  './Data/Mask\\00725.jpg',
#  './Data/Mask\\00726.jpg',
#  './Data/Mask\\00727.jpg',
#  './Data/Mask\\00728.jpg',
#  './Data/Mask\\00729.jpg',
#  './Data/Mask\\00730.jpg',
#  './Data/Mask\\00731.jpg',
#  './Data/Mask\\00732.jpg',
#  './Data/Mask\\00733.jpg',
#  './Data/Mask\\00734.jpg',
#  './Data/Mask\\00735.jpg',
#  './Data/Mask\\00736.jpg',
#  './Data/Mask\\00737.jpg',
#  './Data/Mask\\00738.jpg',
#  './Data/Mask\\00739.jpg',
#  './Data/Mask\\00740.jpg',
#  './Data/Mask\\00741.jpg',
#  './Data/Mask\\00742.jpg',
#  './Data/Mask\\00743.jpg',
#  './Data/Mask\\00744.jpg',
#  './Data/Mask\\00745.jpg',
#  './Data/Mask\\00746.jpg',
#  './Data/Mask\\00747.jpg',
#  './Data/Mask\\00748.jpg',
#  './Data/Mask\\00749.jpg',
#  './Data/Mask\\00750.jpg',
#  './Data/Mask\\00751.jpg',
#  './Data/Mask\\00752.jpg',
#  './Data/Mask\\00753.jpg',
#  './Data/Mask\\00754.jpg',
#  './Data/Mask\\00755.jpg',
#  './Data/Mask\\00756.jpg',
#  './Data/Mask\\00757.jpg',
#  './Data/Mask\\00758.jpg',
#  './Data/Mask\\00759.jpg',
#  './Data/Mask\\00760.jpg',
#  './Data/Mask\\00761.jpg',
#  './Data/Mask\\00762.jpg',
#  './Data/Mask\\00763.jpg',
#  './Data/Mask\\00764.jpg',
#  './Data/Mask\\00765.jpg',
#  './Data/Mask\\00766.jpg',
#  './Data/Mask\\00767.jpg',
#  './Data/Mask\\00768.jpg',
#  './Data/Mask\\00769.jpg',
#  './Data/Mask\\00770.jpg',
#  './Data/Mask\\00771.jpg',
#  './Data/Mask\\00772.jpg',
#  './Data/Mask\\00773.jpg',
#  './Data/Mask\\00774.jpg',
#  './Data/Mask\\00775.jpg',
#  './Data/Mask\\00776.jpg',
#  './Data/Mask\\00777.jpg',
#  './Data/Mask\\00778.jpg',
#  './Data/Mask\\00779.jpg',
#  './Data/Mask\\00780.jpg',
#  './Data/Mask\\00781.jpg',
#  './Data/Mask\\00782.jpg',
#  './Data/Mask\\00783.jpg',
#  './Data/Mask\\00784.jpg',
#  './Data/Mask\\00785.jpg',
#  './Data/Mask\\00786.jpg',
#  './Data/Mask\\00787.jpg',
#  './Data/Mask\\00788.jpg',
#  './Data/Mask\\00789.jpg',
#  './Data/Mask\\00790.jpg',
#  './Data/Mask\\00791.jpg',
#  './Data/Mask\\00792.jpg',
#  './Data/Mask\\00793.jpg',
#  './Data/Mask\\00794.jpg',
#  './Data/Mask\\00795.jpg',
#  './Data/Mask\\00796.jpg',
#  './Data/Mask\\00797.jpg',
#  './Data/Mask\\00798.jpg',
#  './Data/Mask\\00799.jpg',
#  './Data/Mask\\00800.jpg',
#  './Data/Mask\\00801.jpg',
#  './Data/Mask\\00802.jpg',
#  './Data/Mask\\00803.jpg',
#  './Data/Mask\\00804.jpg',
#  './Data/Mask\\00805.jpg',
#  './Data/Mask\\00806.jpg',
#  './Data/Mask\\00807.jpg',
#  './Data/Mask\\00808.jpg',
#  './Data/Mask\\00809.jpg',
#  './Data/Mask\\00810.jpg',
#  './Data/Mask\\00811.jpg',
#  './Data/Mask\\00812.jpg',
#  './Data/Mask\\00813.jpg',
#  './Data/Mask\\00814.jpg',
#  './Data/Mask\\00815.jpg',
#  './Data/Mask\\00816.jpg',
#  './Data/Mask\\00817.jpg',
#  './Data/Mask\\00818.jpg',
#  './Data/Mask\\00819.jpg',
#  './Data/Mask\\00820.jpg',
#  './Data/Mask\\00821.jpg',
#  './Data/Mask\\00822.jpg',
#  './Data/Mask\\00823.jpg',
#  './Data/Mask\\00824.jpg',
#  './Data/Mask\\00825.jpg',
#  './Data/Mask\\00826.jpg',
#  './Data/Mask\\00827.jpg',
#  './Data/Mask\\00828.jpg',
#  './Data/Mask\\00829.jpg',
#  './Data/Mask\\00830.jpg',
#  './Data/Mask\\00831.jpg',
#  './Data/Mask\\00832.jpg',
#  './Data/Mask\\00833.jpg',
#  './Data/Mask\\00834.jpg',
#  './Data/Mask\\00835.jpg',
#  './Data/Mask\\00836.jpg',
#  './Data/Mask\\00837.jpg',
#  './Data/Mask\\00838.jpg',
#  './Data/Mask\\00839.jpg',
#  './Data/Mask\\00840.jpg',
#  './Data/Mask\\00841.jpg',
#  './Data/Mask\\00842.jpg',
#  './Data/Mask\\00843.jpg',
#  './Data/Mask\\00844.jpg',
#  './Data/Mask\\00845.jpg',
#  './Data/Mask\\00846.jpg',
#  './Data/Mask\\00847.jpg',
#  './Data/Mask\\00848.jpg',
#  './Data/Mask\\00849.jpg',
#  './Data/Mask\\00850.jpg',
#  './Data/Mask\\00851.jpg',
#  './Data/Mask\\00852.jpg',
#  './Data/Mask\\00853.jpg',
#  './Data/Mask\\00854.jpg',
#  './Data/Mask\\00855.jpg',
#  './Data/Mask\\00856.jpg',
#  './Data/Mask\\00857.jpg',
#  './Data/Mask\\00858.jpg',
#  './Data/Mask\\00859.jpg',
#  './Data/Mask\\00860.jpg',
#  './Data/Mask\\00861.jpg',
#  './Data/Mask\\00862.jpg',
#  './Data/Mask\\00863.jpg',
#  './Data/Mask\\00864.jpg',
#  './Data/Mask\\00865.jpg',
#  './Data/Mask\\00866.jpg',
#  './Data/Mask\\00867.jpg',
#  './Data/Mask\\00868.jpg',
#  './Data/Mask\\00869.jpg',
#  './Data/Mask\\00870.jpg',
#  './Data/Mask\\00871.jpg',
#  './Data/Mask\\00872.jpg',
#  './Data/Mask\\00873.jpg',
#  './Data/Mask\\00874.jpg',
#  './Data/Mask\\00875.jpg',
#  './Data/Mask\\00876.jpg',
#  './Data/Mask\\00877.jpg',
#  './Data/Mask\\00878.jpg',
#  './Data/Mask\\00879.jpg',
#  './Data/Mask\\00880.jpg',
#  './Data/Mask\\00881.jpg',
#  './Data/Mask\\00882.jpg',
#  './Data/Mask\\00883.jpg',
#  './Data/Mask\\00884.jpg',
#  './Data/Mask\\00885.jpg',
#  './Data/Mask\\00886.jpg',
#  './Data/Mask\\00887.jpg',
#  './Data/Mask\\00888.jpg',
#  './Data/Mask\\00889.jpg',
#  './Data/Mask\\00890.jpg',
#  './Data/Mask\\00891.jpg',
#  './Data/Mask\\00892.jpg',
#  './Data/Mask\\00893.jpg',
#  './Data/Mask\\00894.jpg',
#  './Data/Mask\\00895.jpg',
#  './Data/Mask\\00896.jpg',
#  './Data/Mask\\00897.jpg',
#  './Data/Mask\\00898.jpg',
#  './Data/Mask\\00899.jpg',
#  './Data/Mask\\00900.jpg',
#  './Data/Mask\\00901.jpg',
#  './Data/Mask\\00902.jpg',
#  './Data/Mask\\00903.jpg',
#  './Data/Mask\\00904.jpg',
#  './Data/Mask\\00905.jpg',
#  './Data/Mask\\00906.jpg',
#  './Data/Mask\\00907.jpg',
#  './Data/Mask\\00908.jpg',
#  './Data/Mask\\00909.jpg',
#  './Data/Mask\\00910.jpg',
#  './Data/Mask\\00911.jpg',
#  './Data/Mask\\00912.jpg',
#  './Data/Mask\\00913.jpg',
#  './Data/Mask\\00914.jpg',
#  './Data/Mask\\00915.jpg',
#  './Data/Mask\\00916.jpg',
#  './Data/Mask\\00917.jpg',
#  './Data/Mask\\00918.jpg',
#  './Data/Mask\\00919.jpg',
#  './Data/Mask\\00920.jpg',
#  './Data/Mask\\00921.jpg',
#  './Data/Mask\\00922.jpg',
#  './Data/Mask\\00923.jpg',
#  './Data/Mask\\00924.jpg',
#  './Data/Mask\\00925.jpg',
#  './Data/Mask\\00926.jpg',
#  './Data/Mask\\00927.jpg',
#  './Data/Mask\\00928.jpg',
#  './Data/Mask\\00929.jpg',
#  './Data/Mask\\00930.jpg',
#  './Data/Mask\\00931.jpg',
#  './Data/Mask\\00932.jpg',
#  './Data/Mask\\00933.jpg',
#  './Data/Mask\\00934.jpg',
#  './Data/Mask\\00935.jpg',
#  './Data/Mask\\00936.jpg',
#  './Data/Mask\\00937.jpg',
#  './Data/Mask\\00938.jpg',
#  './Data/Mask\\00939.jpg',
#  './Data/Mask\\00940.jpg',
#  './Data/Mask\\00941.jpg',
#  './Data/Mask\\00942.jpg',
#  './Data/Mask\\00943.jpg',
#  './Data/Mask\\00944.jpg',
#  './Data/Mask\\00945.jpg',
#  './Data/Mask\\00946.jpg',
#  './Data/Mask\\00947.jpg',
#  './Data/Mask\\00948.jpg',
#  './Data/Mask\\00949.jpg',
#  './Data/Mask\\00950.jpg',
#  './Data/Mask\\00951.jpg',
#  './Data/Mask\\00952.jpg',
#  './Data/Mask\\00953.jpg',
#  './Data/Mask\\00954.jpg',
#  './Data/Mask\\00955.jpg',
#  './Data/Mask\\00956.jpg',
#  './Data/Mask\\00957.jpg',
#  './Data/Mask\\00958.jpg',
#  './Data/Mask\\00959.jpg',
#  './Data/Mask\\00960.jpg',
#  './Data/Mask\\00961.jpg',
#  './Data/Mask\\00962.jpg',
#  './Data/Mask\\00963.jpg',
#  './Data/Mask\\00964.jpg',
#  './Data/Mask\\00965.jpg',
#  './Data/Mask\\00966.jpg',
#  './Data/Mask\\00967.jpg',
#  './Data/Mask\\00968.jpg',
#  './Data/Mask\\00969.jpg',
#  './Data/Mask\\00970.jpg',
#  './Data/Mask\\00971.jpg',
#  './Data/Mask\\00972.jpg',
#  './Data/Mask\\00973.jpg',
#  './Data/Mask\\00974.jpg',
#  './Data/Mask\\00975.jpg',
#  './Data/Mask\\00976.jpg',
#  './Data/Mask\\00977.jpg',
#  './Data/Mask\\00978.jpg',
#  './Data/Mask\\00979.jpg',
#  './Data/Mask\\00980.jpg',
#  './Data/Mask\\00981.jpg',
#  './Data/Mask\\00982.jpg',
#  './Data/Mask\\00983.jpg',
#  './Data/Mask\\00984.jpg',
#  './Data/Mask\\00985.jpg',
#  './Data/Mask\\00986.jpg',
#  './Data/Mask\\00987.jpg',
#  './Data/Mask\\00988.jpg',
#  './Data/Mask\\00989.jpg',
#  './Data/Mask\\00990.jpg',
#  './Data/Mask\\00991.jpg',
#  './Data/Mask\\00992.jpg',
#  './Data/Mask\\00993.jpg',
#  './Data/Mask\\00994.jpg',
#  './Data/Mask\\00995.jpg',
#  './Data/Mask\\00996.jpg',
#  './Data/Mask\\00997.jpg',
#  './Data/Mask\\00998.jpg',
#  './Data/Mask\\00999.jpg',
#  ...]

# %%
images_path = []
labels = []
for folder in dirs:
    path = glob('./Data/{}/*.jpg'.format(folder))
    label =['{}'.format(folder)]*len(path) #labelling the pictures according to their category upon which we have named the folder
    # append
    images_path.extend(path)
    labels.extend(label)

# %%
set(labels)
#These are the different labels
# Out:
# {'Mask', 'Mask_Chin', 'Mask_Mouth_Chin', 'Mask_Nose_Mouth'}

# %%
print(images_path)
#List of Path of All Images
# Out:
# ['./Data/Mask\\00000.jpg', './Data/Mask\\00001.jpg', './Data/Mask\\00002.jpg', './Data/Mask\\00003.jpg', './Data/Mask\\00004.jpg', './Data/Mask\\00005.jpg', './Data/Mask\\00006.jpg', './Data/Mask\\00007.jpg', './Data/Mask\\00008.jpg', './Data/Mask\\00009.jpg', './Data/Mask\\00010.jpg', './Data/Mask\\00011.jpg', './Data/Mask\\00012.jpg', './Data/Mask\\00013.jpg', './Data/Mask\\00014.jpg', './Data/Mask\\00015.jpg', './Data/Mask\\00016.jpg', './Data/Mask\\00017.jpg', './Data/Mask\\00018.jpg', './Data/Mask\\00019.jpg', './Data/Mask\\00020.jpg', './Data/Mask\\00021.jpg', './Data/Mask\\00022.jpg', './Data/Mask\\00023.jpg', './Data/Mask\\00024.jpg', './Data/Mask\\00025.jpg', './Data/Mask\\00026.jpg', './Data/Mask\\00027.jpg', './Data/Mask\\00028.jpg', './Data/Mask\\00029.jpg', './Data/Mask\\00030.jpg', './Data/Mask\\00031.jpg', './Data/Mask\\00032.jpg', './Data/Mask\\00033.jpg', './Data/Mask\\00034.jpg', './Data/Mask\\00035.jpg', './Data/Mask\\00036.jpg', './Data/Mask\\00037.jpg', './Data/Mask\\00038.jpg', './Data/Mask\\00039.jpg', './Data/Mask\\00040.jpg', './Data/Mask\\00041.jpg', './Data/Mask\\00042.jpg', './Data/Mask\\00043.jpg', './Data/Mask\\00044.jpg', './Data/Mask\\00045.jpg', './Data/Mask\\00046.jpg', './Data/Mask\\00047.jpg', './Data/Mask\\00048.jpg', './Data/Mask\\00049.jpg', './Data/Mask\\00050.jpg', './Data/Mask\\00051.jpg', './Data/Mask\\00052.jpg', './Data/Mask\\00053.jpg', './Data/Mask\\00054.jpg', './Data/Mask\\00055.jpg', './Data/Mask\\00056.jpg', './Data/Mask\\00057.jpg', './Data/Mask\\00058.jpg', './Data/Mask\\00059.jpg', './Data/Mask\\00060.jpg', './Data/Mask\\00061.jpg', './Data/Mask\\00062.jpg', './Data/Mask\\00063.jpg', './Data/Mask\\00064.jpg', './Data/Mask\\00065.jpg', './Data/Mask\\00066.jpg', './Data/Mask\\00067.jpg', './Data/Mask\\00068.jpg', './Data/Mask\\00069.jpg', './Data/Mask\\00070.jpg', './Data/Mask\\00071.jpg', './Data/Mask\\00072.jpg', './Data/Mask\\00073.jpg', './Data/Mask\\00074.jpg', './Data/Mask\\00075.jpg', './Data/Mask\\00076.jpg', './Data/Mask\\00077.jpg', './Data/Mask\\00078.jpg', './Data/Mask\\00079.jpg', './Data/Mask\\00080.jpg', './Data/Mask\\00081.jpg', './Data/Mask\\00082.jpg', './Data/Mask\\00083.jpg', './Data/Mask\\00084.jpg', './Data/Mask\\00085.jpg', './Data/Mask\\00086.jpg', './Data/Mask\\00087.jpg', './Data/Mask\\00088.jpg', './Data/Mask\\00089.jpg', './Data/Mask\\00090.jpg', './Data/Mask\\00091.jpg', './Data/Mask\\00092.jpg', './Data/Mask\\00093.jpg', './Data/Mask\\00094.jpg', './Data/Mask\\00095.jpg', './Data/Mask\\00096.jpg', './Data/Mask\\00097.jpg', './Data/Mask\\00098.jpg', './Data/Mask\\00099.jpg', './Data/Mask\\00100.jpg', './Data/Mask\\00101.jpg', './Data/Mask\\00102.jpg', './Data/Mask\\00103.jpg', './Data/Mask\\00104.jpg', './Data/Mask\\00105.jpg', './Data/Mask\\00106.jpg', './Data/Mask\\00107.jpg', './Data/Mask\\00108.jpg', './Data/Mask\\00109.jpg', './Data/Mask\\00110.jpg', './Data/Mask\\00111.jpg', './Data/Mask\\00112.jpg', './Data/Mask\\00113.jpg', './Data/Mask\\00114.jpg', './Data/Mask\\00115.jpg', './Data/Mask\\00116.jpg', './Data/Mask\\00117.jpg', './Data/Mask\\00118.jpg', './Data/Mask\\00119.jpg', './Data/Mask\\00120.jpg', './Data/Mask\\00121.jpg', './Data/Mask\\00122.jpg', './Data/Mask\\00123.jpg', './Data/Mask\\00124.jpg', './Data/Mask\\00125.jpg', './Data/Mask\\00126.jpg', './Data/Mask\\00127.jpg', './Data/Mask\\00128.jpg', './Data/Mask\\00129.jpg', './Data/Mask\\00130.jpg', './Data/Mask\\00131.jpg', './Data/Mask\\00132.jpg', './Data/Mask\\00133.jpg', './Data/Mask\\00134.jpg', './Data/Mask\\00135.jpg', './Data/Mask\\00136.jpg', './Data/Mask\\00137.jpg', './Data/Mask\\00138.jpg', './Data/Mask\\00139.jpg', './Data/Mask\\00140.jpg', './Data/Mask\\00141.jpg', './Data/Mask\\00142.jpg', './Data/Mask\\00143.jpg', './Data/Mask\\00144.jpg', './Data/Mask\\00145.jpg', './Data/Mask\\00146.jpg', './Data/Mask\\00147.jpg', './Data/Mask\\00148.jpg', './Data/Mask\\00149.jpg', './Data/Mask\\00150.jpg', './Data/Mask\\00151.jpg', './Data/Mask\\00152.jpg', './Data/Mask\\00153.j ...

# %% [markdown]
# ### Face Detection & Cropping
# - Face Detection - We will use the pre-trained deep neural network model
# - Cropping

# %% [markdown]
# In OpenCV we have a module called DNN (OpenCV-> Deep Neural Network), we will use the Face Detection (FP16) model.

# %% [markdown]
# #### To Download
#
# res10_300x300_ssd_iter_140000_fp16.caffemodel -
#
# https://github.com/opencv/opencv_3rdparty/raw/19512576c112aa2c7b6328cb0e8d589a4a90a26d/res10_300x300_ssd_iter_140000_fp16.caffemodel
#
# deploy.prototxt -
#
# https://github.com/opencv/opencv/blob/master/samples/dnn/face_detector/deploy.prototxt

# %%
img_path = images_path[1]
img = cv2.imread(img_path) #reading the image using OpenCV

# %%
cv2.imshow('original',img) #looking at the image we are working on now
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# Now we will detect the face and draw a bounding box on top of the face using OpenCV and Deep Neural Networks

# %%
# Loading the face detection model (Caffe Model). Alternatives can be Tendorflow or Torch
face_detection_model = cv2.dnn.readNetFromCaffe('./models/deploy.prototxt.txt',
                                                './models/res10_300x300_ssd_iter_140000_fp16.caffemodel')

# %% [markdown]
# Now we need to calculate the blob from image, i.e RGB Mean Subtraction
#
# A Blob, in a sense, is anything that is considered a large object or anything bright in a dark background, in images, we can generalize it as a group of pixel values that forms a somewhat colony or a large object that is distinguishable from its background. Using image processing, we can detect such blobs in an image

# %%
def face_detection_dnn(img):
    # blob from image (rgb mean subraction image)
    image = img.copy() # making a copy of the original image
    h,w = image.shape[:2] # calculating the height and width. Originally we get the height, width and depth but here we need only the height and width so [:2]
    #calculating blob from image using cv2
    blob = cv2.dnn.blobFromImage(image,1,(300,300),(104,117,123),swapRB=True) # resizing to 300x300 because our model is trained for 300x300 images, the next is the RGB mean values(the mean value is from imagenet dataset {https://www.image-net.org/})
    # get the detections to pass to the face_detection_model
    face_detection_model.setInput(blob)
    detections = face_detection_model.forward() #Forward Pass
    #print(detections)
    #print(detections.shape) -> (1, 1, 200, 7) [[  [ [1,2,..7], .. 200 arrays ]  ]]
    for i in range(0,detections.shape[2]): #we want to evalulate the confidence score for all 200 boxes
        confidence = detections[0,0,i,2] # confidence score
        #print(confidence) -> 200 scores ranging from 0.0 to 1.0
        if confidence > 0.5: # filtering the score greater than 0.5 (we get only one mostly)
            box = detections[0,0,i,3:7]*np.array([w,h,w,h]) #bounding box information is from 3 to 7, multiplying with w,h,w,h to normalize the array
            box = box.astype(int) #converting the floating point values to integers
            #print(box) -> [216, 142, 802, 801] 
            pt1 = (box[0],box[1])
            pt2 = (box[2],box[3])
            #cv2.rectangle(image,pt1,pt2,(0,255,0),2)
            roi = image[box[1]:box[3],box[0]:box[2]] # cropping the image by keeping only the region of interest

            return roi # if face is detected we are returning the region of interest(cropped image)
    return None # returning None if no face is detected

# %%
img_roi = face_detection_dnn(img) # testing the function

# %%
cv2.imshow('roi',img_roi)
cv2.imshow('original',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### Blob from Image (RGB Mean Subtraction):
# - Blob from image (Feature extraction process)

# %%
def datapreprocess(img):
    # blob from image (rgb mean subtraction image)
    face = face_detection_dnn(img)
    if face is not None:

        # computing blob from image
        blob = cv2.dnn.blobFromImage(face,1,(100,100),(104,117,123),swapRB=True)
        #print(bolb.shape) -> (1, 3, 100, 100)
        blob_squeeze = np.squeeze(blob).T # reducing the dimension of the image and taking transpose for getting height, width, depth from original depth, width, height
        #print(blob_squueze.shape) -> (3, 103, 100)
        
        #rotating and flipping to bring the blob image to the original orientation 
        blob_rotate = cv2.rotate(blob_squeeze,cv2.ROTATE_90_CLOCKWISE)
        blob_flip = cv2.flip(blob_rotate,1)
        
        # remove negative values and normalize it into 0 to 1 range
        img_norm = np.maximum(blob_flip,0)/blob_flip.max()
    
        return img_norm
    
    else:
        
        return None

# %% [markdown]
# ### Applying the same to all the images in the dataset and appending it into a List

# %%
#len(images_path) -> 10000, took nearly 13 minutes to process the changes below

data_img = []
label_img = []
i = 0
for path, label in tqdm(zip(images_path,labels),desc='preprocessing'):
    img = cv2.imread(path) # reading the image
    process_img = datapreprocess(img)
    if process_img is not None:
        data_img.append(process_img)
        label_img.append(label)
          
    i += 1
    if i%100 == 0: # for every 100 iterations, we are clearing the garbage memory
        gc.collect()
# Out:
# preprocessing: 10000it [12:56, 12.89it/s]

# %%
X = np.array(data_img)
y = np.array(label_img)

# %%
X.shape, y.shape
# Out:
# ((9959, 100, 100, 3), (9959,))

# %%
np.savez('./data/data_preprocess.npz',X,y) #zipping and saving our data into npz format (NumPyZip)

# %% [markdown]
# ## END
